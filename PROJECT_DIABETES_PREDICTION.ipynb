# %% [markdown]
# ![SHIV.png](data:image/png;base64,...)

# %% [markdown]
# # ***DIABETES PREDICTION DATASET:-***
#
# # [DIABETES PREDICTION](https://github.com/ybifoundation/Dataset/raw/main/Diabetes.csv)

# %% [markdown]
# # LINKS:-https://github.com/ybifoundation/Dataset/raw/main/Diabetes.csv

# %%
import numpy as np

# %%
import pandas as pd

# %%
pf=pd.read_csv('https://github.com/ybifoundation/Dataset/raw/main/Diabetes.csv')

# %%
pf
# Out:
#      pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age  \
# 0              6      148         72       35        0  33.6  0.627   50
# 1              1       85         66       29        0  26.6  0.351   31
# 2              8      183         64        0        0  23.3  0.672   32
# 3              1       89         66       23       94  28.1  0.167   21
# 4              0      137         40       35      168  43.1  2.288   33
# ..           ...      ...        ...      ...      ...   ...    ...  ...
# 763           10      101         76       48      180  32.9  0.171   63
# 764            2      122         70       27        0  36.8  0.340   27
# 765            5      121         72       23      112  26.2  0.245   30
# 766            1      126         60        0        0  30.1  0.349   47
# 767            1       93         70       31        0  30.4  0.315   23
#
#      diabetes
# 0           1
# 1           0
# 2           1
# 3           0
# ...

# %%
pf.head()
# Out:
#    pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age  \
# 0            6      148         72       35        0  33.6  0.627   50
# 1            1       85         66       29        0  26.6  0.351   31
# 2            8      183         64        0        0  23.3  0.672   32
# 3            1       89         66       23       94  28.1  0.167   21
# 4            0      137         40       35      168  43.1  2.288   33
#
#    diabetes
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1

# %%
pf.tail()
# Out:
#      pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age  \
# 763           10      101         76       48      180  32.9  0.171   63
# 764            2      122         70       27        0  36.8  0.340   27
# 765            5      121         72       23      112  26.2  0.245   30
# 766            1      126         60        0        0  30.1  0.349   47
# 767            1       93         70       31        0  30.4  0.315   23
#
#      diabetes
# 763         0
# 764         0
# 765         0
# 766         1
# 767         0

# %%
pf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   pregnancies  768 non-null    int64
#  1   glucose      768 non-null    int64
#  2   diastolic    768 non-null    int64
#  3   triceps      768 non-null    int64
#  4   insulin      768 non-null    int64
#  5   bmi          768 non-null    float64
#  6   dpf          768 non-null    float64
#  7   age          768 non-null    int64
#  8   diabetes     768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
pf.describe()
# Out:
#        pregnancies     glucose   diastolic     triceps     insulin  \
# count   768.000000  768.000000  768.000000  768.000000  768.000000
# mean      3.845052  120.894531   69.105469   20.536458   79.799479
# std       3.369578   31.972618   19.355807   15.952218  115.244002
# min       0.000000    0.000000    0.000000    0.000000    0.000000
# 25%       1.000000   99.000000   62.000000    0.000000    0.000000
# 50%       3.000000  117.000000   72.000000   23.000000   30.500000
# 75%       6.000000  140.250000   80.000000   32.000000  127.250000
# max      17.000000  199.000000  122.000000   99.000000  846.000000
#
#               bmi         dpf         age    diabetes
# count  768.000000  768.000000  768.000000  768.000000
# mean    31.992578    0.471876   33.240885    0.348958
# std      7.884160    0.331329   11.760232    0.476951
# min      0.000000    0.078000   21.000000    0.000000
# 25%     27.300000    0.243750   24.000000    0.000000
# ...

# %%
pf.dtypes
# Out:
# pregnancies      int64
# glucose          int64
# diastolic        int64
# triceps          int64
# insulin          int64
# bmi            float64
# dpf            float64
# age              int64
# diabetes         int64
# dtype: object

# %%
pf.age
# Out:
# 0      50
# 1      31
# 2      32
# 3      21
# 4      33
#        ..
# 763    63
# 764    27
# 765    30
# 766    47
# 767    23
# Name: age, Length: 768, dtype: int64

# %%
pf.nunique()
# Out:
# pregnancies     17
# glucose        136
# diastolic       47
# triceps         51
# insulin        186
# bmi            248
# dpf            517
# age             52
# diabetes         2
# dtype: int64

# %%
pf.shape
# Out:
# (768, 9)

# %% [markdown]
# # Define x and y

# %%
pf.columns
# Out:
# Index(['pregnancies', 'glucose', 'diastolic', 'triceps', 'insulin', 'bmi',
#        'dpf', 'age', 'diabetes'],
#       dtype='object')

# %%
y=pf['diabetes']

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: diabetes, Length: 768, dtype: int64

# %%
y.shape
# Out:
# (768,)

# %%
x=pf[['pregnancies', 'glucose', 'diastolic', 'triceps', 'insulin', 'bmi',
       'dpf', 'age']]

# %%
x
# Out:
#      pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age
# 0              6      148         72       35        0  33.6  0.627   50
# 1              1       85         66       29        0  26.6  0.351   31
# 2              8      183         64        0        0  23.3  0.672   32
# 3              1       89         66       23       94  28.1  0.167   21
# 4              0      137         40       35      168  43.1  2.288   33
# ..           ...      ...        ...      ...      ...   ...    ...  ...
# 763           10      101         76       48      180  32.9  0.171   63
# 764            2      122         70       27        0  36.8  0.340   27
# 765            5      121         72       23      112  26.2  0.245   30
# 766            1      126         60        0        0  30.1  0.349   47
# 767            1       93         70       31        0  30.4  0.315   23
#
# [768 rows x 8 columns]

# %%
x.shape
# Out:
# (768, 8)

# %% [markdown]
# # Train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((614, 8), (154, 8), (614,), (154,))

# %%
x_train
# Out:
#      pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age
# 600            1      108         88       19        0  27.1  0.400   24
# 227            3      162         52       38        0  37.2  0.652   24
# 534            1       77         56       30       56  33.3  1.251   24
# 367            0      101         64       17        0  21.0  0.252   21
# 141            5      106         82       30        0  39.5  0.286   38
# ..           ...      ...        ...      ...      ...   ...    ...  ...
# 606            1      181         78       42      293  40.0  1.258   22
# 293            1      128         48       45      194  40.5  0.613   24
# 174            2       75         64       24       55  29.7  0.370   33
# 745           12      100         84       33      105  30.0  0.488   46
# 268            0      102         52        0        0  25.1  0.078   21
#
# [614 rows x 8 columns]

# %%
y_test
# Out:
# 620    0
# 690    0
# 24     1
# 306    1
# 207    1
#       ..
# 200    0
# 345    0
# 430    0
# 63     0
# 433    0
# Name: diabetes, Length: 154, dtype: int64

# %%
x_test
# Out:
#      pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age
# 620            2      112         86       42      160  38.4  0.246   28
# 690            8      107         80        0        0  24.6  0.856   34
# 24            11      143         94       33      146  36.6  0.254   51
# 306           10      161         68       23      132  25.5  0.326   47
# 207            5      162        104        0        0  37.7  0.151   52
# ..           ...      ...        ...      ...      ...   ...    ...  ...
# 200            0      113         80       16        0  31.0  0.874   21
# 345            8      126         88       36      108  38.5  0.349   49
# 430            2       99          0        0        0  22.2  0.108   23
# 63             2      141         58       34      128  25.4  0.699   24
# 433            2      139         75        0        0  25.6  0.167   29
#
# [154 rows x 8 columns]

# %%
y_train
# Out:
# 600    0
# 227    1
# 534    0
# 367    0
# 141    0
#       ..
# 606    1
# 293    1
# 174    0
# 745    0
# 268    0
# Name: diabetes, Length: 614, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([ 0.2282027 ,  0.35519553,  0.64665129,  0.65105038,  0.62639821,
#         0.6639519 ,  0.46824582, -0.02520387,  0.67444862,  0.4294034 ,
#         0.01050211,  0.13472305,  0.29127282,  0.32079161,  0.32280115,
#         0.40991317,  0.45979807,  0.75755065,  0.10264835,  0.4766493 ,
#         0.11788009,  0.13804081,  0.4446658 ,  0.04413021,  0.09349551,
#         0.29405239,  0.08725947,  0.40209401,  0.60217624, -0.02188713,
#         0.24483573,  0.53860978,  0.60202004,  0.34915921,  0.50593579,
#         0.03731246,  0.22342394,  0.06363689,  0.28116729,  0.05699367,
#         1.30534784,  0.181524  ,  0.09266372,  0.45157005,  0.33774785,
#         0.11525803,  0.17784502, -0.44715737, -0.15792887,  0.8279419 ,
#         0.4032129 ,  0.04223253,  0.34798181,  0.22299122,  0.24693931,
#         0.25200801,  0.64636374,  0.11780701,  0.69687005,  0.11856095,
#         0.25554585,  0.36573169,  0.62815518,  0.13791419,  0.64700036,
# ...

# %%
y_pred.shape
# Out:
# (154,)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model1=KNeighborsClassifier()

# %%
model1.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred1=model1.predict(x_test)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
model2=KNeighborsRegressor()

# %%
model2.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred2=model2.predict(x_train)

# %%
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error, mean_squared_error

# %%
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 907334152951535.4

# %%
mean_absolute_percentage_error(y_test,y_pred1)
# Out:
# 701859682187609.8

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 0.33795874825651673

# %%
mean_absolute_error(y_test,y_pred1)
# Out:
# 0.2662337662337662

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
pf.isnull().sum()
# Out:
# pregnancies    0
# glucose        0
# diastolic      0
# triceps        0
# insulin        0
# bmi            0
# dpf            0
# age            0
# diabetes       0
# dtype: int64

# %%
sns.countplot(x=pf['diabetes'],hue='pregnancies',data=pf)

# %%
sns.countplot(x=pf['diabetes'],hue='glucose',data=pf)

# %%
sns.countplot(x=pf['diabetes'],hue='diastolic',data=pf)

# %%
sns.countplot(x=pf['diabetes'],hue='triceps',data=pf)

# %%
sns.countplot(x=pf['diabetes'],hue='insulin',data=pf)

# %%
sns.countplot(x=pf['diabetes'],hue='bmi',data=pf)

# %%
sns.countplot(x=pf['diabetes'],hue='dpf',data=pf)

# %%
sns.countplot(x=pf['diabetes'],hue='age',data=pf)

# %%
sns.countplot(x=pf['diabetes'],hue='diabetes',data=pf)

# %%
sns.countplot(x=pf['age'],hue='pregnancies',data=pf)

# %%
sns.stripplot(x=pf['glucose'],hue='pregnancies',data=pf)

# %%
sns.swarmplot(x=pf['glucose'],hue='pregnancies',data=pf)

# %%
sns.barplot(x=pf['glucose'],hue='pregnancies',data=pf)

# %%
sns.boxplot(x=pf['glucose'],hue='pregnancies',data=pf)

# %%
sns.violinplot(x=pf['glucose'],hue='pregnancies',data=pf)

# %%
sns.histplot(x=pf['glucose'],hue='pregnancies',data=pf)

# %%
sns.pairplot(pf, hue ='age')

# %%
y = np.array([35, 25, 25, 15])

# %%
plt.pie(y)
plt.show()
